# %% [markdown]
# # Algollusion\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom algollusion import AlgollusionCalculator\n

# %%
df = pd.read_csv("algollusion_dataset.csv")\ndf.head()\n

# %%
calc = AlgollusionCalculator()\nresult = calc.calculate_algollusion(df)\nresult.head()\n

# %%
result["algollusion_index"].describe()\n

# %%
result.groupby("algollusion_band").size()\n

# %%
result["algollusion_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Algollusion` index is now ready for stress testing.
